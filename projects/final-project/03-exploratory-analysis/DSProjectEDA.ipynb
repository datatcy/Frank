# %%
import pandas as pd

data = pd.read_csv('dataset/DSProjectData.csv', skipinitialspace=True, low_memory=False)

# %%
data.count()
# Out:
# Server Name    520
# Week           520
# CPU %          510
# RAM            510
# Date           520
# dtype: int64

# %%
data.describe()
# Out:
#             CPU %         RAM
# count  510.000000  510.000000
# mean     2.530170   12.019804
# std      5.615617    6.779015
# min      0.014100    4.100000
# 25%      0.227500    7.800000
# 50%      0.735000    9.100000
# 75%      1.627500   15.075000
# max     39.000000   28.130000

# %%
data.plot(kind='box')

# %%
data['Date'].unique()
# Out:
# array(['1/7/2017', '1/14/2017', '1/21/2017', '1/28/2017', '2/4/2017',
#        '2/11/2017', '2/18/2017', '2/25/2017', '3/4/2017', '3/11/2017',
#        '3/18/2017', '3/25/2017', '4/1/2017', '4/8/2017', '4/15/2017',
#        '4/22/2017', '4/29/2017', '5/6/2017', '5/13/2017', '5/20/2017',
#        '5/27/2017', '6/3/2017', '6/10/2017', '6/17/2017', '6/24/2017',
#        '7/1/2017', '7/8/2017', '7/15/2017', '7/22/2017', '7/29/2017',
#        '8/5/2017', '8/12/2017', '8/19/2017', '8/26/2017', '9/2/2017',
#        '9/9/2017', '9/16/2017', '9/23/2017', '9/30/2017', '10/7/2017',
#        '10/14/2017', '10/21/2017', '10/28/2017', '11/4/2017', '11/11/2017',
#        '11/18/2017', '11/25/2017', '12/2/2017', '12/9/2017', '12/16/2017',
#        '12/23/2017', '12/30/2017'], dtype=object)

# %%
#data.set_index('Date', inplace=True)

#data['Year'] = data.index.year
#data['Month'] = data.index.month

# %%
data['Date']=pd.to_datetime(data['Date'])

# %%
data=data.sort_values('Date')

# %%
data.head()
# Out:
#     Server Name  Week  CPU %   RAM       Date
# 0    CALBIPRD01  Wk 1  0.226   6.2 2017-01-07
# 364  CALBIPRD08  Wk 1  1.020  10.1 2017-01-07
# 312  CALBIPRD07  Wk 1  2.670   6.1 2017-01-07
# 260  CALBIPRD06  Wk 1  0.368   5.2 2017-01-07
# 208  CALBIPRD05  Wk 1  0.274   5.7 2017-01-07

# %%
data['Server Name'].unique()
# Out:
# array(['CALBIPRD01', 'CALBIPRD08', 'CALBIPRD07', 'CALBIPRD06',
#        'CALBIPRD05', 'CALMFRRSQL', 'CALBIPRD04', 'CALBIPRD03',
#        'CALBIPRD02', 'CALBITST05'], dtype=object)

# %%
prd01= data[data['Server Name'] == 'CALBIPRD01']

# %% [markdown]
# <B>CALPBPRD01 CPU %<B>

# %%
prd01.plot(kind='line', figsize=(50,10), fontsize=30 , legend=True, linewidth=5.0, x='Date', y='RAM', color ='red')

# %% [markdown]
# <B>CALBIPRD01 RAM</B>

# %%
prd01.plot(kind='line', figsize=(50,10), fontsize=30 , legend=True, linewidth=5.0, x='Date', y='CPU %', 
           title='PRD01-CPU %')

# %% [markdown]
# <B>CALBIPRD01 CPU % AND RAM</B>

# %%
prd01.plot(kind='line', figsize=(50,10), fontsize=30 , legend=True, linewidth=5.0, x='Date',
           title='PRD01-CPU% & RAM')

# %% [markdown]
# <b>CALBIPRD02 CPU % AND RAM</b>

# %%
prd02= data[data['Server Name'] == 'CALBIPRD02']
prd02.plot(kind='line', figsize=(50,10), fontsize=30 , legend=True, linewidth=5.0, x='Date',
           title='PRD01-CPU% & RAM')

# %% [markdown]
# <b>CALBIPRD03 CPU % AND RAM</b>

# %%
prd03= data[data['Server Name'] == 'CALBIPRD03']
prd03.plot(kind='line', figsize=(50,10), fontsize=30 , legend=True, linewidth=5.0, x='Date',
           title='PRD01-CPU% & RAM')

# %% [markdown]
# <b>CALBIPRD04 CPU % AND RAM</b>

# %%
prd04= data[data['Server Name'] == 'CALBIPRD04']
prd04.plot(kind='line', figsize=(50,10), fontsize=30 , legend=True, linewidth=5.0, x='Date',
           title='PRD01-CPU% & RAM')

# %% [markdown]
# <b>CALBIPRD05 CPU % AND RAM</b>

# %%
prd05= data[data['Server Name'] == 'CALBIPRD05']
prd05.plot(kind='line', figsize=(50,10), fontsize=30 , legend=True, linewidth=5.0, x='Date',
           title='PRD01-CPU% & RAM')

# %% [markdown]
# <b>CALBIPRD06 CPU % AND RAM</b>

# %%
prd06= data[data['Server Name'] == 'CALBIPRD06']
prd06.plot(kind='line', figsize=(50,10), fontsize=30 , legend=True, linewidth=5.0, x='Date',
           title='PRD01-CPU% & RAM')

# %% [markdown]
# <b>CALBIPRD07 CPU % AND RAM</b>

# %%
prd07= data[data['Server Name'] == 'CALBIPRD07']
prd07.plot(kind='line', figsize=(50,10), fontsize=30 , legend=True, linewidth=5.0, x='Date',
           title='PRD01-CPU% & RAM')

# %% [markdown]
# <b>CALBIPRD08 CPU % AND RAM</b>

# %%
prd08= data[data['Server Name'] == 'CALBIPRD08']
prd08.plot(kind='line', figsize=(50,10), fontsize=30 , legend=True, linewidth=5.0, x='Date',
           title='PRD01-CPU% & RAM')

# %% [markdown]
# <b>CALSQL CPU % AND RAM</b>

# %%
prdsql= data[data['Server Name'] == 'CALMFRRSQL']
prdsql.plot(kind='line', figsize=(50,10), fontsize=30 , legend=True, linewidth=5.0, x='Date',
           title='PRD01-CPU% & RAM')

# %% [markdown]
# <b>CALBIPTST CPU % AND RAM</b>

# %%
bitst= data[data['Server Name'] == 'CALBITST05']
bitst.plot(kind='line', figsize=(50,10), fontsize=30 , legend=True, linewidth=5.0, x='Date',
           title='PRD01-CPU% & RAM')

# %%
data_all= data[(data['CPU %']<=3)].sort_values('CPU %')
#data_all=data[data['RAM'] <=20]
#data_all.plot(kind='box')
#data_all

# %%
#data_all.plot(kind='line', figsize=(50,10), fontsize=30 , legend=True, linewidth=5.0,  y='CPU %', x='Date',
 #          title='All Servers CPU')

# %%
#data_all.plot(kind='line', figsize=(50,10), fontsize=30 , legend=True, linewidth=5.0, y='RAM', x='Date',
     #      title='All Servers RAM', color='red')

# %%
#data_all.plot(kind='line', figsize=(50,10), fontsize=30 , legend=True, linewidth=5.0, x='Date')

# %%
import pandas as pd

eda_time = pd.read_csv('dataset/DSProjectData.csv', skipinitialspace=True, low_memory=False)
eda_time['Date'] = pd.to_datetime(data['Date'])
eda_time.set_index('Date', inplace=True)

#data.set_index('Date', inplace=True)
#data['Year'] = data.index.year
#data['Month'] = data.index.month
#eda_time['Year']=eda_time.i
eda_time['Month']= eda_time.index.month
eda_time['Day']=eda_time.index.day

# %%
eda_time.head()
# Out:
#            Server Name  Week   CPU %  RAM  Month  Day
# Date
# 2017-01-07  CALBIPRD01  Wk 1  0.2260  6.2      1    7
# 2017-01-14  CALBIPRD01  Wk 2  0.1264  6.2      1   14
# 2017-01-21  CALBIPRD01  Wk 3  0.4300  5.6      1   21
# 2017-01-28  CALBIPRD01  Wk 4  0.0850  5.7      1   28
# 2017-02-04  CALBIPRD01  Wk 5  0.1200  6.2      2    4

# %%
#eda_time['Server Name'].unique()

# %%
#eda_time=eda_time[eda_time['Server Name'] in ('CALMFRRSQL','CALBITST05')]

# %%
#pd.rolling_median(eda_time[['CPU %']], window=1, center=True).plot(figsize=(50,10),fontsize=30 , 
 #                                                                  legend=True, linewidth=5.0)

# %%
#eda_time=eda_time[eda_time['Ser'] == 'CALBIPRD01']
#(eda_time['2017'][['CPU %']]<=10).plot(figsize=(50,10),fontsize=30 , legend=True, linewidth=5.0)

# %%
import seaborn as sb
# %matplotlib inline

sb.factorplot(
    #col='Open',
    x='Server Name',
    y='CPU %',
    data=eda_time, 
    kind='box',
    size=10
)

sb.factorplot(
    #col='Open',
    x='Server Name',
    #hue='Promo',
    y='RAM',
    data=eda_time, 
    kind='box',
    size=10
)

# %% [markdown]
# <B>CALBIPRD01 CPU% (Rolling One Month)</B>

# %%
eda_time01=eda_time[eda_time['Server Name']=='CALBIPRD01']
#eda_time01=eda_time[eda_time['CPU %'] <= 5]
eda_time01[['CPU %']].resample('M', how =['mean','median']).rolling(window =1, center =True).mean().plot()
#eda_time01[['RAM']].resample('M', how =['median','mean']).plot()
# Out:
# /Users/francispaulraj/anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:3: FutureWarning: how in .resample() is deprecated
# the new syntax is .resample(...)..apply(<func>)
#   This is separate from the ipykernel package so we can avoid doing imports until

# %% [markdown]
# <B>CALBIPRD01 RAM (Rolling One Month)</B>

# %%
eda_time01=eda_time[eda_time['Server Name']=='CALBIPRD01'] 
#eda_time01=eda_time[eda_time['RAM'] <= 13]
eda_time01[['RAM']].resample('M', how =['mean','median']).rolling(window =1, center =True).mean().plot()
# Out:
# /Users/francispaulraj/anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:3: FutureWarning: how in .resample() is deprecated
# the new syntax is .resample(...)..apply(<func>)
#   This is separate from the ipykernel package so we can avoid doing imports until

# %% [markdown]
# <B>CALBIPRD02 CPU% (Rolling One Month)</B>

# %%
eda_time02=eda_time[eda_time['Server Name']=='CALBIPRD02']
#eda_time02=eda_time[eda_time['CPU %'] <= 5]
eda_time02[['CPU %']].resample('M', how =['mean','median']).rolling(window =1, center =True).mean().plot()
# Out:
# /Users/francispaulraj/anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:3: FutureWarning: how in .resample() is deprecated
# the new syntax is .resample(...)..apply(<func>)
#   This is separate from the ipykernel package so we can avoid doing imports until

# %% [markdown]
# <B>CALBIPRD02 RAM (Rolling One Month)</B>

# %%
eda_time02=eda_time[eda_time['Server Name']=='CALBIPRD02']
eda_time02[['RAM']].resample('M', how =['mean','median']).rolling(window =1, center =True).mean().plot()
# Out:
# /Users/francispaulraj/anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:2: FutureWarning: how in .resample() is deprecated
# the new syntax is .resample(...)..apply(<func>)

# %% [markdown]
# <B>CALBIPRD03 CPU% (Rolling One Month)</B>

# %%
eda_time03=eda_time[eda_time['Server Name']=='CALBIPRD03']
#eda_time03=eda_time[eda_time['CPU %'] <= 5]
eda_time03[['CPU %']].resample('M', how =['mean','median']).rolling(window =1, center =True).mean().plot()
# Out:
# /Users/francispaulraj/anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:3: FutureWarning: how in .resample() is deprecated
# the new syntax is .resample(...)..apply(<func>)
#   This is separate from the ipykernel package so we can avoid doing imports until

# %% [markdown]
# <B>CALBIPRD03 RAM (Rolling One Month)</B>

# %%
eda_time03=eda_time[eda_time['Server Name']=='CALBIPRD03']
eda_time03[['RAM']].resample('M', how =['mean','median']).rolling(window =1, center =True).mean().plot()
# Out:
# /Users/francispaulraj/anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:2: FutureWarning: how in .resample() is deprecated
# the new syntax is .resample(...)..apply(<func>)

# %% [markdown]
# <B>CALBIPRD04 CPU% (Rolling One Month)</B>

# %%
eda_time04=eda_time[eda_time['Server Name']=='CALBIPRD04']
#eda_time04=eda_time[eda_time['CPU %'] <= 5]
eda_time04[['CPU %']].resample('M', how =['mean','median']).rolling(window =1, center =True).mean().plot()
# Out:
# /Users/francispaulraj/anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:3: FutureWarning: how in .resample() is deprecated
# the new syntax is .resample(...)..apply(<func>)
#   This is separate from the ipykernel package so we can avoid doing imports until

# %% [markdown]
# <B>CALBIPRD04 RAM (Rolling One Month)</B>

# %%
eda_time04=eda_time[eda_time['Server Name']=='CALBIPRD04']
eda_time04[['RAM']].resample('M', how =['mean','median']).rolling(window =1, center =True).mean().plot()
# Out:
# /Users/francispaulraj/anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:2: FutureWarning: how in .resample() is deprecated
# the new syntax is .resample(...)..apply(<func>)

# %% [markdown]
# <B>CALBIPRD05 CPU% (Rolling One Month)</B>

# %%
eda_time05=eda_time[eda_time['Server Name']=='CALBIPRD05']
#eda_time05=eda_time[eda_time['CPU %'] <= 5]
eda_time05[['CPU %']].resample('M', how =['mean','median']).rolling(window =1, center =True).mean().plot()
# Out:
# /Users/francispaulraj/anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:3: FutureWarning: how in .resample() is deprecated
# the new syntax is .resample(...)..apply(<func>)
#   This is separate from the ipykernel package so we can avoid doing imports until

# %% [markdown]
# <B>CALBIPRD05 RAM (Rolling One Month)</B>

# %%
eda_time05=eda_time[eda_time['Server Name']=='CALBIPRD05']
eda_time05[['RAM']].resample('M', how =['mean','median']).rolling(window =1, center =True).mean().plot()
# Out:
# /Users/francispaulraj/anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:2: FutureWarning: how in .resample() is deprecated
# the new syntax is .resample(...)..apply(<func>)

# %% [markdown]
# <B>CALBIPRD06 CPU% (Rolling One Month)</B>

# %%
eda_time06=eda_time[eda_time['Server Name']=='CALBIPRD06']
#eda_time06=eda_time[eda_time['CPU %'] <= 5]
eda_time06[['CPU %']].resample('M', how =['mean','median']).rolling(window =1, center =True).mean().plot()
# Out:
# /Users/francispaulraj/anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:3: FutureWarning: how in .resample() is deprecated
# the new syntax is .resample(...)..apply(<func>)
#   This is separate from the ipykernel package so we can avoid doing imports until

# %% [markdown]
# <B>CALBIPRD06 RAM (Rolling One Month)</B>

# %%
eda_time06=eda_time[eda_time['Server Name']=='CALBIPRD06']
#eda_time06=eda_time[eda_time['RAM'] <= 9]
eda_time06[['RAM']].resample('M', how =['mean','median']).rolling(window =1, center =True).mean().plot()
# Out:
# /Users/francispaulraj/anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:3: FutureWarning: how in .resample() is deprecated
# the new syntax is .resample(...)..apply(<func>)
#   This is separate from the ipykernel package so we can avoid doing imports until

# %% [markdown]
# <B>CALBIPRD07 CPU % (Rolling One Month)</B>

# %%
eda_time07=eda_time[eda_time['Server Name']=='CALBIPRD07']
#eda_time01=eda_time[eda_time['CPU %'] <= 5]
eda_time07[['CPU %']].resample('M', how =['mean','median']).rolling(window =1, center =True).mean().plot()
# Out:
# /Users/francispaulraj/anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:3: FutureWarning: how in .resample() is deprecated
# the new syntax is .resample(...)..apply(<func>)
#   This is separate from the ipykernel package so we can avoid doing imports until

# %% [markdown]
# <B>CALBIPRD07 RAM (Rolling One Month)</B>

# %%
eda_time07=eda_time[eda_time['Server Name']=='CALBIPRD07']
eda_time07[['RAM']].resample('M', how =['mean','median']).rolling(window =1, center =True).mean().plot()
# Out:
# /Users/francispaulraj/anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:2: FutureWarning: how in .resample() is deprecated
# the new syntax is .resample(...)..apply(<func>)

# %% [markdown]
# <B>CALBIPRD08 CPU % (Rolling One Month)</B>

# %%
eda_time08=eda_time[eda_time['Server Name']=='CALBIPRD08']
eda_time08[['CPU %']].resample('M', how =['mean','median']).rolling(window =1, center =True).mean().plot()
# Out:
# /Users/francispaulraj/anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:2: FutureWarning: how in .resample() is deprecated
# the new syntax is .resample(...)..apply(<func>)

# %% [markdown]
# <B>CALBIPRD08 RAM (Rolling One Month)</B>

# %%
eda_time08=eda_time[eda_time['Server Name']=='CALBIPRD08']
eda_time08[['RAM']].resample('M', how =['mean','median']).rolling(window =1, center =True).mean().plot()
# Out:
# /Users/francispaulraj/anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:2: FutureWarning: how in .resample() is deprecated
# the new syntax is .resample(...)..apply(<func>)

# %% [markdown]
# <B>CALMFRSQL CPU% (Rolling One Month)</B>

# %%
eda_timesq=eda_time[eda_time['Server Name']=='CALMFRRSQL']
eda_timesq[['CPU %']].resample('M', how =['mean','median']).rolling(window =1, center =True).mean().plot()
# Out:
# /Users/francispaulraj/anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:2: FutureWarning: how in .resample() is deprecated
# the new syntax is .resample(...)..apply(<func>)

# %% [markdown]
# <B>CALMFRSQL RAM (Rolling One Month)</B>

# %%
eda_timesq=eda_time[eda_time['Server Name']=='CALMFRRSQL']
##eda_timesq=eda_time[eda_time['RAM'] >= 25]
eda_timesq[['RAM']].resample('M', how =['mean','median']).rolling(window =1, center =True).mean().plot()
# Out:
# /Users/francispaulraj/anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:3: FutureWarning: how in .resample() is deprecated
# the new syntax is .resample(...)..apply(<func>)
#   This is separate from the ipykernel package so we can avoid doing imports until

# %% [markdown]
# <B>CALBITST05 CPU% (Rolling One Month)</B>

# %%
eda_timet5=eda_time[eda_time['Server Name']=='CALBITST05']
eda_timet5[['CPU %']].resample('M', how =['mean','median']).rolling(window =1, center =True).mean().plot()
# Out:
# /Users/francispaulraj/anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:2: FutureWarning: how in .resample() is deprecated
# the new syntax is .resample(...)..apply(<func>)

# %% [markdown]
# <B>CALBITST05 RAM (Rolling One Month)</B>

# %%
eda_timet5=eda_time[eda_time['Server Name']=='CALBITST05']
eda_timet5[['RAM']].resample('M', how =['mean','median']).rolling(window =1, center =True).mean().plot()
# Out:
# /Users/francispaulraj/anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:2: FutureWarning: how in .resample() is deprecated
# the new syntax is .resample(...)..apply(<func>)

# %% [markdown]
# <b>Autocorrlation for CPU % - Month Difference<b>

# %%
print 'CALBIPRD01 CPU % Corr', eda_time01['CPU %'].resample('M').mean().autocorr(lag=1)
print 'CALBIPRD02 CPU % Corr', eda_time02['CPU %'].resample('M').mean().autocorr(lag=1)
print 'CALBIPRD03 CPU % Corr', eda_time03['CPU %'].resample('M').mean().autocorr(lag=1)
print 'CALBIPRD04 CPU % Corr', eda_time04['CPU %'].resample('M').mean().autocorr(lag=1)
print 'CALBIPRD05 CPU % Corr', eda_time05['CPU %'].resample('M').mean().autocorr(lag=1)
print 'CALBIPRD06 CPU % Corr', eda_time06['CPU %'].resample('M').mean().autocorr(lag=1)
print 'CALBIPRD07 CPU % Corr', eda_time07['CPU %'].resample('M').mean().autocorr(lag=1)
print 'CALBIPRD08 CPU % Corr', eda_time08['CPU %'].resample('M').mean().autocorr(lag=1)
print 'CALMFRSQL  CPU % Corr', eda_timesq['CPU %'].resample('M').mean().autocorr(lag=1)
print 'CALBITST05 CPU % Corr', eda_timet5['CPU %'].resample('M').mean().autocorr(lag=1)
# Out:
# CALBIPRD01 CPU % Corr 0.390819340872
# CALBIPRD02 CPU % Corr 0.559483723358
# CALBIPRD03 CPU % Corr 0.775600057858
# CALBIPRD04 CPU % Corr 0.722036189605
# CALBIPRD05 CPU % Corr 0.897792604572
# CALBIPRD06 CPU % Corr 0.582063388227
# CALBIPRD07 CPU % Corr 0.649443296174
# CALBIPRD08 CPU % Corr 0.651721536689
# CALMFRSQL  CPU % Corr 0.686596704251
# CALBITST05 CPU % Corr 0.746621211628

# %% [markdown]
# <b>Autocorrlation for RAM - Month Difference<b>

# %%
print 'CALBIPRD01 RAM Corr', eda_time01['RAM'].resample('M').mean().autocorr(lag=1)
print 'CALBIPRD02 RAM Corr', eda_time02['RAM'].resample('M').mean().autocorr(lag=1)
print 'CALBIPRD03 RAM Corr', eda_time03['RAM'].resample('M').mean().autocorr(lag=1)
print 'CALBIPRD04 RAM Corr', eda_time04['RAM'].resample('M').mean().autocorr(lag=1)
print 'CALBIPRD05 RAM Corr', eda_time05['RAM'].resample('M').mean().autocorr(lag=1)
print 'CALBIPRD06 RAM Corr', eda_time06['RAM'].resample('M').mean().autocorr(lag=1)
print 'CALBIPRD07 RAM Corr', eda_time07['RAM'].resample('M').mean().autocorr(lag=1)
print 'CALBIPRD08 RAM Corr', eda_time08['RAM'].resample('M').mean().autocorr(lag=1)
print 'CALMFRSQL  RAM Corr', eda_timesq['RAM'].resample('M').mean().autocorr(lag=1)
print 'CALBITST05 RAM Corr', eda_timet5['RAM'].resample('M').mean().autocorr(lag=1)
# Out:
# CALBIPRD01 RAM Corr 0.355656845976
# CALBIPRD02 RAM Corr 0.859875698003
# CALBIPRD03 RAM Corr 0.866490999893
# CALBIPRD04 RAM Corr 0.838958418194
# CALBIPRD05 RAM Corr 0.898370029695
# CALBIPRD06 RAM Corr 0.219901602643
# CALBIPRD07 RAM Corr 0.908807745446
# CALBIPRD08 RAM Corr 0.957846342904
# CALMFRSQL  RAM Corr 0.0764183408959
# CALBITST05 RAM Corr 0.450693222108
